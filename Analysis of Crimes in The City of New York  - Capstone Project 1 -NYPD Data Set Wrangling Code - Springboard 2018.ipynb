# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NYPD_Complaint_Data_Current_YTD.csv")
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   579468609   12/31/2017     23:55:00          NaN          NaN  12/31/2017
# 1   822699000   12/31/2017     23:30:00          NaN          NaN  12/31/2017
# 2   187081621   12/31/2017     23:10:00   12/31/2017     23:15:00  12/31/2017
# 3   967006956   12/31/2017     23:05:00   12/31/2017     23:15:00  12/31/2017
# 4   524297993   12/31/2017     23:00:00          NaN          NaN  12/31/2017
#
#    KY_CD                     OFNS_DESC  PD_CD                     PD_DESC  \
# 0    118             DANGEROUS WEAPONS  792.0    WEAPONS POSSESSION 1 & 2
# 1    344  ASSAULT 3 & RELATED OFFENSES  114.0         OBSTR BREATH/CIRCUL
# 2    578                 HARRASSMENT 2  637.0  HARASSMENT,SUBD 1,CIVILIAN
# 3    118             DANGEROUS WEAPONS  793.0        WEAPONS POSSESSION 3
# 4    118             DANGEROUS WEAPONS  792.0    WEAPONS POSSESSION 1 & 2
#
#     ...    ADDR_PCT_CD LOC_OF_OCCUR_DESC               PREM_TYP_DESC PARKS_NM  \
# 0   ...             67               NaN                      STREET      NaN
# 1   ...             47          FRONT OF      RESIDENCE - APT. HOUSE      NaN
# 2   ...             23            INSIDE  RESIDENCE - PUBLIC HOUSING      NaN
# 3   ...             73            INSIDE             RESIDENCE-HOUSE      NaN
# 4   ...             61          FRONT OF      RESIDENCE - APT. HOUSE      NaN
#
#    HADEVELOPT X_COORD_CD Y_COORD_CD Latitude Longitude  Lat_Lon
# 0         NaN        NaN        NaN      NaN       NaN      NaN
# 1         NaN        NaN        NaN      NaN       NaN      NaN
# 2         NaN        NaN        NaN      NaN       NaN      NaN
# 3         NaN        NaN        NaN      NaN       NaN      NaN
# 4         NaN        NaN        NaN      NaN       NaN      NaN
#
# [5 rows x 24 columns]

# %%
dfh=pd.read_csv("NYPD_Complaint_Data_Historic.csv")
# Out:
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dft1=pd.concat([df,dfh])

# %%
#I don't need greater level of granularity location than a borough so I drop cooridates columns
# I don't need information about park name or jurisdication responsible for the incident so I drop those columns as well
#dft1 = dft.drop(columns = ['X_COORD_CD','Y_COORD_CD','Latitude','Longitude',"Lat_Lon", 'PARKS_NM','JURIS_DESC'])
#keeping the coordinates

# %%
#hadevelopt has many NaNs so I drop this column too 
dft1=dft1.drop(columns="HADEVELOPT")

# %%
#the information about ending date can be used to fill out missing information about CMPLNT_FR_DT
df3=dft1[['CMPLNT_FR_DT','CMPLNT_TO_DT','RPT_DT']]
#df3[df3['CMPLNT_FR_DT'].isnull()]
df3.tail()

# %%
#filling out nans in complaint date
def datef(row):
    
    if pd.isnull(row["CMPLNT_FR_DT"]):
        if pd.notnull((row["CMPLNT_TO_DT"])):
            return row["CMPLNT_TO_DT"]
        elif pd.notnull(row['RPT_DT']):
            return row['RPT_DT']
        else: 
            return row["CMPLNT_FR_DT"]
    else: 
        return row["CMPLNT_FR_DT"]

# %%
dft1["CMPLNT_FR_DT"]=dft1.apply(datef,axis=1)

# %%
dft1.count()

# %% [markdown]
# There is two more columns I will get rid of CMPLNT_TO_DT and CMPLNT_TO_TM - I only need a date of crime and optionally a time.
# I can also drop RPT_DT since I am more interested in the date of the crime and usually reporting date is close to date of crime.
# LOC_OF_OCCUR_DESC is also incomplete in one third so I will drop this column too.

# %%
dft2=dft1.drop(columns=['CMPLNT_TO_DT',
       'CMPLNT_TO_TM', 'RPT_DT','LOC_OF_OCCUR_DESC'])
#dft2.info()

# %%
dft2.rename(columns={'CMPLNT_NUM':'ComplaintID', 'CMPLNT_FR_DT':'Date','CMPLNT_FR_TM':'Time',"KY_CD":"Offence Code",'OFNS_DESC':'Description','PD_CD':'Internal Code',
 'PD_DESC':'Internal Description',
 'CRM_ATPT_CPTD_CD':'Status',
 'LAW_CAT_CD':'Offence Level',
 'BORO_NM':'Borough',
 'ADDR_PCT_CD':'Neighborhood',
 'PREM_TYP_DESC':'Premise Description'}, inplace=True)

dft2.reset_index(inplace=True)
dft2.drop(columns='index')
# Out:
#          ComplaintID        Date      Time  Offence Code  \
# 0          579468609  12/31/2017  23:55:00           118
# 1          822699000  12/31/2017  23:30:00           344
# 2          187081621  12/31/2017  23:10:00           578
# 3          967006956  12/31/2017  23:05:00           118
# 4          524297993  12/31/2017  23:00:00           118
# 5          656720558  12/31/2017  23:00:00           351
# 6          259728915  12/31/2017  23:00:00           118
# 7          643915940  12/31/2017  23:00:00           344
# 8          309983236  12/31/2017  22:53:00           235
# 9          322611002  12/31/2017  22:50:00           106
# 10         368332678  12/31/2017  22:50:00           344
# 11         535753203  12/31/2017  22:48:00           117
# 12         235604904  12/31/2017  22:45:00           344
# 13         456356513  12/31/2017  22:45:00           344
# 14         503982784  12/31/2017  22:45:00           347
# 15         613621102  12/31/2017  22:43:00           236
# 16         153330592  12/31/2017  22:40:00           341
# 17         876217930  12/31/2017  22:34:00           341
# 18         723858595  12/31/2017  22:30:00           578
# 19         433420451  12/31/2017  22:25:00           348
# 20         218190176  12/31/2017  22:20:00           359
# 21         894207833  12/31/2017  22:15:00           344
# 22         843574703  12/31/2017  22:12:00           233
# 23         269795299  12/31/2017  22:10:00           105
# 24         269513847  12/31/2017  22:10:00           344
# 25         599530104  12/31/2017  22:10:00           344
# 26         358958258  12/31/2017  22:10:00           344
# 27         423128346  12/31/2017  22:05:00           348
# 28         682365690  12/31/2017  22:01:00           343
# 29         728548889  12/31/2017  22:00:00           351
# ...              ...         ...       ...           ...
# 6048766    933830947  12/15/2015  15:00:00           361
# 6048767    385852521  12/13/2015  23:45:00           107
# 6048768    333423940  12/13/2015  11:00:00           358
# 6048769    172033613  12/13/2015  05:24:00           114
# 6048770    319148578  12/11/2015  09:00:00           109
# 6048771    189785942  12/09/2015  12:00:00           578
# 6048772    524352522  12/07/2015  16:00:00           578
# 6048773    803388972  12/03/2015  18:10:00           109
# 6048771                   HARRASSMENT 2          638.0
# 6048772                   HARRASSMENT 2          638.0
# 6048773                   GRAND LARCENY          418.0
# 6048774                   GRAND LARCENY          421.0
# 6048775                           ARSON          264.0
# 6048776                   HARRASSMENT 2          638.0
# 6048777                   HARRASSMENT 2          638.0
# 6048778   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 6048779                      SEX CRIMES          175.0
# 6048780                           ARSON          264.0
# 6048781   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 6048782   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 6048783                 DANGEROUS DRUGS          503.0
# 6048784                   HARRASSMENT 2          637.0
# 6048785                   HARRASSMENT 2          638.0
# 6048786                  FELONY ASSAULT          109.0
# 6048787                   HARRASSMENT 2          637.0
# 6048788                   HARRASSMENT 2          637.0
# 6048789    ASSAULT 3 & RELATED OFFENSES          101.0
# 6048790                         ROBBERY          382.0
# 6048791                         ROBBERY          399.0
# 6048792                   HARRASSMENT 2          638.0
# 6048793                  FELONY ASSAULT          109.0
# 6048794   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 6048795                        BURGLARY          213.0
#
#                                  Internal Description     Status  \
# 0                            WEAPONS POSSESSION 1 & 2  COMPLETED
# 1                                 OBSTR BREATH/CIRCUL  COMPLETED
# 2                          HARASSMENT,SUBD 1,CIVILIAN  COMPLETED
# 3                                WEAPONS POSSESSION 3  COMPLETED
# 4                            WEAPONS POSSESSION 1 & 2  COMPLETED
# 5                      MISCHIEF, CRIMINAL 4, OF MOTOR  COMPLETED
# 6                                WEAPONS POSSESSION 3  COMPLETED
# 7                                           ASSAULT 3  COMPLETED
# 8                         MARIJUANA, POSSESSION 4 & 5  COMPLETED
# 9                            ASSAULT 2,1,UNCLASSIFIED  COMPLETED
# 10                                          ASSAULT 3  COMPLETED
# 11                      CONTROLLED SUBSTANCE,POSSESS.  COMPLETED
# 12                                          ASSAULT 3  COMPLETED
# 13                                          ASSAULT 3  COMPLETED
# 14                        INTOXICATED DRIVING,ALCOHOL  COMPLETED
# 15                           WEAPONS, POSSESSION, ETC  COMPLETED
# 16                     LARCENY,PETIT FROM STORE-SHOPL  COMPLETED
# 17                     LARCENY,PETIT FROM STORE-SHOPL  COMPLETED
# 18                         HARASSMENT,SUBD 1,CIVILIAN  COMPLETED
# 19                     LEAVING SCENE-ACCIDENT-PERSONA  COMPLETED
# 20                     VIOLATION OF ORDER OF PROTECTI  COMPLETED
# 21                                          ASSAULT 3  COMPLETED
# 22                         CHILD, ENDANGERING WELFARE  COMPLETED
# 23                     ROBBERY,OPEN AREA UNCLASSIFIED  COMPLETED
# 24                                          ASSAULT 3  COMPLETED
# 25                                          ASSAULT 3  COMPLETED
# 26                                          ASSAULT 3  COMPLETED
# 27                     LEAVING SCENE-ACCIDENT-PERSONA  COMPLETED
# 28                     THEFT OF SERVICES, UNCLASSIFIE  COMPLETED
# 29                   CRIMINAL MISCHIEF,UNCLASSIFIED 4  COMPLETED
# ...                                               ...        ...
# 6048766                       AGGRAVATED HARASSMENT 2  COMPLETED
# 6048767                      BURGLARY,RESIDENCE,NIGHT  COMPLETED
# 6048768                            FORGERY,ETC.-MISD.  COMPLETED
# 6048769                ARSON, MOTOR VEHICLE 1 2 3 & 4  COMPLETED
# 6048770  LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)  COMPLETED
# 6048771                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048772                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048773   LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD  COMPLETED
# 6048774         LARCENY,GRAND FROM VEHICLE/MOTORCYCLE  COMPLETED
# 6048775                ARSON, MOTOR VEHICLE 1 2 3 & 4  COMPLETED
# 6048776                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048777                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048778                       AGGRAVATED HARASSMENT 2  COMPLETED
# 6048779                              SEXUAL ABUSE 3,2  COMPLETED
# 6048780                ARSON, MOTOR VEHICLE 1 2 3 & 4  COMPLETED
# 6048781                       AGGRAVATED HARASSMENT 2  COMPLETED
# 6048782                       AGGRAVATED HARASSMENT 2  COMPLETED
# 6048783                CONTROLLED SUBSTANCE,INTENT TO  COMPLETED
# 6048784                    HARASSMENT,SUBD 1,CIVILIAN  COMPLETED
# 6048785                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048786                      ASSAULT 2,1,UNCLASSIFIED  COMPLETED
# 6048787                    HARASSMENT,SUBD 1,CIVILIAN  COMPLETED
# 6048788                    HARASSMENT,SUBD 1,CIVILIAN  COMPLETED
# 6048789                                     ASSAULT 3  COMPLETED
# 6048790                     ROBBERY,NECKCHAIN/JEWELRY  COMPLETED
# 6048791               ROBBERY,COMMERCIAL UNCLASSIFIED  COMPLETED
# 6048792                         HARASSMENT,SUBD 3,4,5  COMPLETED
# 6048793                      ASSAULT 2,1,UNCLASSIFIED  COMPLETED
# 6048794                       AGGRAVATED HARASSMENT 2  COMPLETED
# 6048795                     BURGLARY,COMMERCIAL,NIGHT  COMPLETED
#
#         Offence Level           JURIS_DESC        Borough  Neighborhood  \
# 0              FELONY     N.Y. POLICE DEPT       BROOKLYN          67.0
# 1         MISDEMEANOR     N.Y. POLICE DEPT          BRONX          47.0
# 2           VIOLATION  N.Y. HOUSING POLICE      MANHATTAN          23.0
# 3              FELONY     N.Y. POLICE DEPT       BROOKLYN          73.0
# 4              FELONY     N.Y. POLICE DEPT       BROOKLYN          61.0
# 5         MISDEMEANOR     N.Y. POLICE DEPT       BROOKLYN          61.0
# 6              FELONY  N.Y. HOUSING POLICE       BROOKLYN          83.0
# 7         MISDEMEANOR     N.Y. POLICE DEPT         QUEENS
# 6048789   MISDEMEANOR     N.Y. POLICE DEPT          BRONX          41.0
# 6048790        FELONY     N.Y. POLICE DEPT         QUEENS         109.0
# 6048791        FELONY     N.Y. POLICE DEPT      MANHATTAN          30.0
# 6048792     VIOLATION  N.Y. TRANSIT POLICE          BRONX          41.0
# 6048793        FELONY     N.Y. POLICE DEPT         QUEENS         109.0
# 6048794   MISDEMEANOR     N.Y. POLICE DEPT          BRONX          50.0
# 6048795        FELONY     N.Y. POLICE DEPT       BROOKLYN          84.0
#
#                 Premise Description PARKS_NM  X_COORD_CD  Y_COORD_CD  \
# 0                            STREET      NaN         NaN         NaN
# 1            RESIDENCE - APT. HOUSE      NaN         NaN         NaN
# 2        RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 3                   RESIDENCE-HOUSE      NaN         NaN         NaN
# 4            RESIDENCE - APT. HOUSE      NaN         NaN         NaN
# 5                            STREET      NaN         NaN         NaN
# 6        RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 7                   RESIDENCE-HOUSE      NaN         NaN         NaN
# 8                            STREET      NaN         NaN         NaN
# 9        RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 10                           STREET      NaN         NaN         NaN
# 11                           STREET      NaN         NaN         NaN
# 12       RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 13                  RESIDENCE-HOUSE      NaN         NaN         NaN
# 14                           STREET      NaN         NaN         NaN
# 15                BUS (NYC TRANSIT)      NaN         NaN         NaN
# 16                       DRUG STORE      NaN         NaN         NaN
# 17                       DRUG STORE      NaN         NaN         NaN
# 18                  RESIDENCE-HOUSE      NaN         NaN         NaN
# 19                           STREET      NaN         NaN         NaN
# 20       RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 21                        FAST FOOD      NaN         NaN         NaN
# 22                           STREET      NaN         NaN         NaN
# 23                           STREET      NaN         NaN         NaN
# 24       RESIDENCE - PUBLIC HOUSING      NaN         NaN         NaN
# 25                           STREET      NaN         NaN         NaN
# 26           RESIDENCE - APT. HOUSE      NaN         NaN         NaN
# 27                           STREET      NaN         NaN         NaN
# 28           TAXI (YELLOW LICENSED)      NaN         NaN         NaN
# 29           RESIDENCE - APT. HOUSE      NaN         NaN         NaN
# ...                             ...      ...         ...         ...
# 6048766             RESIDENCE-HOUSE      NaN   1037293.0    192746.0
# 6048767             RESIDENCE-HOUSE      NaN   1037225.0    202542.0
# 6048768      RESIDENCE - APT. HOUSE      NaN   1024130.0    242706.0
# 6048769                      STREET      NaN   1025454.0    177909.0
# 6048770      RESIDENCE - APT. HOUSE      NaN   1005740.0    182009.0
# 6048771             RESIDENCE-HOUSE      NaN   1024986.0    180365.0
# 6048772      RESIDENCE - APT. HOUSE      NaN   1039968.0    203714.0
# 6048773           BUS (NYC TRANSIT)      NaN   1045257.0    224658.0
# 6048774                      STREET      NaN   1000780.0    152466.0
# 6048775                      STREET      NaN   1026259.0    181590.0
# 6048776      RESIDENCE - APT. HOUSE      NaN   1032707.0    253408.0
# 6048777      RESIDENCE - APT. HOUSE      NaN   1024736.0    250167.0
# 6048778      RESIDENCE - APT. HOUSE      NaN   1000641.0    242672.0
# 6048779      RESIDENCE - APT. HOUSE      NaN         NaN         NaN
# 6048780                      STREET      NaN   1028403.0    176642.0
# 6048781  RESIDENCE - PUBLIC HOUSING      NaN   1041071.0    193698.0
# 6048782             RESIDENCE-HOUSE      NaN    948098.0    145446.0
# 6048783                       OTHER      NaN    995118.0    155709.0
# 6048784  RESIDENCE - PUBLIC HOUSING      NaN    984492.0    198617.0
# 6048785  RESIDENCE - PUBLIC HOUSING      NaN   1009554.0    258698.0
# 6048786             PUBLIC BUILDING      NaN   1015693.0    180982.0
# 6048787      RESIDENCE - APT. HOUSE      NaN   1009950.0    192049.0
# 6048788             RESIDENCE-HOUSE      NaN   1038616.0    214409.0
# 6048789      RESIDENCE - APT. HOUSE      NaN   1013080.0    240805.0
# 6048790                      STREET      NaN   1032890.0    216576.0
# 6048791                 HOTEL/MOTEL      NaN    998372.0    240146.0
# 6048792        TRANSIT - NYC SUBWAY      NaN   1014468.0    238156.0
# 6048793              BAR/NIGHT CLUB      NaN   1030529.0    214093.0
# 6048794      RESIDENCE - APT. HOUSE      NaN   1009735.0    261272.0
# 6048795               PUBLIC SCHOOL      NaN    989682.0    188334.0
#
#           Latitude  Longitude                        Lat_Lon
# 0              NaN        NaN                            NaN
# 1              NaN        NaN                            NaN
# 2              NaN        NaN                            NaN
# 3              NaN        NaN                            NaN
# 4              NaN        NaN                            NaN
# 5              NaN        NaN                            NaN
# 6              NaN        NaN                            NaN
# 7              NaN        NaN                            NaN
# 8              NaN        NaN                            NaN
# 9              NaN        NaN                            NaN
# 10             NaN        NaN                            NaN
# 11             NaN        NaN                            NaN
# 12             NaN        NaN                            NaN
# 13             NaN        NaN                            NaN
# 14             NaN        NaN                            NaN
# 15             NaN        NaN                            NaN
# 16             NaN        NaN                            NaN
# 17             NaN        NaN                            NaN
# 18             NaN        NaN                            NaN
# 19             NaN        NaN                            NaN
# 20             NaN        NaN                            NaN
# 21             NaN        NaN                            NaN
# 22             NaN        NaN                            NaN
# 23             NaN        NaN                            NaN
# 24             NaN        NaN                            NaN
# 25             NaN        NaN                            NaN
# 26             NaN        NaN                            NaN
# 27             NaN        NaN                            NaN
# 28             NaN        NaN                            NaN
# 29             NaN        NaN                            NaN
# ...            ...        ...                            ...
# 6048766  40.695569 -73.808717  (40.695569276, -73.808716935)
# 6048767  40.722457 -73.808885  (40.722457324, -73.808885084)
# 6048768  40.832765 -73.855889  (40.832765499, -73.855889059)
# 6048769  40.654908 -73.851502  (40.654908142, -73.851501534)
# 6048770  40.666232 -73.922538  (40.666231521, -73.922538001)
# 6048771  40.661651 -73.853173   (40.66165148, -73.853173375)
# 6048772  40.725657 -73.798980  (40.725657321, -73.798979574)
# 6048773  40.783108 -73.779708  (40.783108212, -73.779707737)
# 6048774  40.585153 -73.940489   (40.585152843, -73.94048929)
# 6048775  40.665008 -73.848577  (40.665007882, -73.848577374)
# 6048776  40.862096 -73.824818   (40.86209639, -73.824817512)
# 6048777  40.853241 -73.853654   (40.85324098, -73.853654148)
# 6048778  40.832747 -73.940770  (40.832747006, -73.940770142)
# 6048779        NaN        NaN                            NaN
# 6048780  40.651416 -73.840882  (40.651416297, -73.840881606)
# 6048781  40.698159 -73.795085  (40.698158838, -73.795084668)
# 6048782  40.565826 -74.130120  (40.565826024, -74.130120092)
# 6048783  40.594063 -73.960869   (40.59406298, -73.960868693)
# 6048784  40.711843 -73.999129  (40.711842747, -73.999128529)
# 6048785  40.876713 -73.908501  (40.876712543, -73.908501223)
# 6048786  40.663383 -73.886666  (40.663382884, -73.886665968)
# 6048787  40.693778 -73.907324  (40.693777815, -73.907324243)
# 6048788  40.755021 -73.803771  (40.755020782, -73.803770928)
# 6048789  40.827591 -73.895828  (40.827590785, -73.895828025)
# 6048790  40.761002 -73.824423  (40.761001984, -73.824422813)
# 6048791  40.825818 -73.948975  (40.825817778, -73.948974825)
# 6048792  40.820315 -73.890825  (40.820315396, -73.890824603)
# 6048793  40.754199 -73.832963  (40.754199468, -73.832962523)
# 6048794  40.883777 -73.907837  (40.883776851, -73.907836928)
# 6048795  40.683617 -73.980416  (40.683616638, -73.980416007)
#
# [6048796 rows x 19 columns]

# %%
# to save some memory I will assign Borough, Status, Offence Level as 'category'
dft2['Borough']=dft2['Borough'].astype('category')
dft2['Offence Code']=dft2['Offence Code'].astype('category')
dft2['Internal Code']=dft2['Internal Code'].astype('category')
dft2['Status']=dft2['Status'].astype('category')
dft2['Offence Level']=dft2['Offence Level'].astype('category')
dft2['Neighborhood']=dft2['Neighborhood'].astype('category')

# %%
dft2.drop(columns=['Unnamed: 0','index'],inplace=True)

# %%
dft2['Year']=dft2.Date.str[-4:]
dft2['Month']=dft2.Date.str[-7:-5]

# %%
dft2[dft2['Year']=='1015']

# %%
dft2.groupby(by='Year')['ComplaintID'].count()

# %% [markdown]
# There is some weird year dates that probably were typed by mistake, also I am not interested in data before 2006

# %%
dft2=dft2[(dft2['Year']=='2017') | (dft2['Year']=='2016' ) | (dft2['Year']=='2015' )|(dft2['Year']=='2014')|(dft2['Year']=='2013' )|(dft2['Year']=='2012' )|(dft2['Year']=='2011' )|(dft2['Year']=='2010' )|(dft2['Year']=='2009' )|(dft2['Year']=='2008' )|(dft2['Year']=='2007' )|(dft2['Year']=='2006' )]

# %%
dft2['Datetime'] = dft2['Date'] + ' ' + dft2['Time']
# Out:
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dft2.tail()
# Out:
#            index  ComplaintID        Date      Time Offence Code  \
# 6048790  5580029    593729461  01/01/2015  04:30:00          105
# 6048791  5580030    582350583  01/01/2015  03:50:00          105
# 6048792  5580031    258046495  01/01/2015  01:25:00          578
# 6048793  5580032    640212578  01/01/2015  00:30:00          106
# 6048794  5580033    496500431  06/30/2014  12:00:00          361
#
#                            Description Internal Code  \
# 6048790                        ROBBERY         382.0
# 6048791                        ROBBERY         399.0
# 6048792                  HARRASSMENT 2         638.0
# 6048793                 FELONY ASSAULT         109.0
# 6048794  OFF. AGNST PUB ORD SENSBLTY &         639.0
#
#                     Internal Description     Status Offence Level  \
# 6048790        ROBBERY,NECKCHAIN/JEWELRY  COMPLETED        FELONY
# 6048791  ROBBERY,COMMERCIAL UNCLASSIFIED  COMPLETED        FELONY
# 6048792            HARASSMENT,SUBD 3,4,5  COMPLETED     VIOLATION
# 6048793         ASSAULT 2,1,UNCLASSIFIED  COMPLETED        FELONY
# 6048794          AGGRAVATED HARASSMENT 2  COMPLETED   MISDEMEANOR
#
#                 ...              Premise Description PARKS_NM X_COORD_CD  \
# 6048790         ...                           STREET      NaN  1032890.0
# 6048791         ...                      HOTEL/MOTEL      NaN   998372.0
# 6048792         ...             TRANSIT - NYC SUBWAY      NaN  1014468.0
# 6048793         ...                   BAR/NIGHT CLUB      NaN  1030529.0
# 6048794         ...           RESIDENCE - APT. HOUSE      NaN  1009735.0
#
#         Y_COORD_CD   Latitude  Longitude                        Lat_Lon  Year  \
# 6048790   216576.0  40.761002 -73.824423  (40.761001984, -73.824422813)  2015
# 6048791   240146.0  40.825818 -73.948975  (40.825817778, -73.948974825)  2015
# 6048792   238156.0  40.820315 -73.890825  (40.820315396, -73.890824603)  2015
# 6048793   214093.0  40.754199 -73.832963  (40.754199468, -73.832962523)  2015
# 6048794   261272.0  40.883777 -73.907837  (40.883776851, -73.907836928)  2014
#
#          Month             Datetime
# 6048790     01  01/01/2015 04:30:00
# 6048791     01  01/01/2015 03:50:00
# 6048792     01  01/01/2015 01:25:00
# 6048793     01  01/01/2015 00:30:00
# 6048794     30  06/30/2014 12:00:00
#
# [5 rows x 23 columns]

# %%
dft2["Date"] =pd.to_datetime(dft2['Date'], format='%m/%d/%Y')
# Out:
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dft2.set_index('Date',inplace=True)

# %%
dft2.drop(columns='Datetime',inplace=True)
dft2['Borough']=dft2['Borough'].astype('category')
dft2['Offence Code']=dft2['Offence Code'].astype('category')
dft2['Internal Code']=dft2['Internal Code'].astype('category')
dft2['Status']=dft2['Status'].astype('category')
dft2['Offence Level']=dft2['Offence Level'].astype('category')
dft2['Neighborhood']=dft2['Neighborhood'].astype('category')
dft2['Year']=dft2['Year'].astype('category')
dft2['Month']=dft2['Month'].astype('category')
# Out:
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#changing numerical data into str and then into categorical data
#dft2['Neighborhood']=dft2["Neighborhood"].astype(int).astype(str).astype('category')
dft2['Internal Code']=dft2["Internal Code"].astype(int).astype(str).astype('category')
dft2['Offence Code']=dft2["Offence Code"].astype(str).astype('category')
# Out:
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/michalczapski/anaconda/envs/aind/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#saving to pickle
dft2.to_pickle("NYPD_data_clean_coord")

# %%
#saving to CSV
dft2.to_csv("NYPD_data_clean_coord.csv")
